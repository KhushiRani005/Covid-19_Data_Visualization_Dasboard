# %%
# !pip install pandas matplotlib seaborn plotly
# Out:
# Requirement already satisfied: pandas in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (6.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from plotly) (2.22.1)
# Requirement already satisfied: six>=1.5 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\KHUSHI RANI\Desktop\Data_Visualization_Dashboard

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'app.ipynb', 'covid_data.csv', 'requirements.txt']

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\KHUSHI RANI\Desktop\Data_Visualization_Dashboard\covid_data.csv")
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
print(df.head())
print(df.info())
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB
# None

# %%
df = df.dropna()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
print(df.columns.tolist())
# Out:
# ['Province/State', 'Country/Region', 'Lat', 'Long', 'Date', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'WHO Region']

# %%
df['Date'] = pd.to_datetime(df['Date'])

df = df[['Country/Region',
         'Date',
         'Confirmed',
         'Deaths',
         'Recovered',
         'Active']]

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.58.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Using cached altair-6.2.1-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Using cached cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: click<9,>=7.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (8.1.8)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Using cached gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (2.2.4)
# Requirement already satisfied: packaging>=20 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (12.2.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Using cached pydeck-0.9.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Collecting pyarrow>=7.0 (from streamlit)
#   Using cached pyarrow-24.0.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (4.12.2)
# Collecting starlette>=0.40.0 (from streamlit)
#   Using cached starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Using cached uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Using cached httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from streamlit) (4.6.2)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Using cached python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Collecting websockets>=12.0.0 (from streamlit)
#   Using cached websockets-16.0-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Requirement already satisfied: jinja2 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.1)
# Requirement already satisfied: idna>=2.8 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from anyio>=4.0.0->streamlit) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from anyio>=4.0.0->streamlit) (1.3.0)
# Requirement already satisfied: colorama in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: h11>=0.8 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.14.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\khushi rani\.conda\envs\mynewenv\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.16.0)
# Using cached streamlit-1.58.0-py3-none-any.whl (9.2 MB)
# Using cached altair-6.2.1-py3-none-any.whl (797 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-7.1.4-py3-none-any.whl (16 kB)
# Using cached gitpython-3.1.50-py3-none-any.whl (212 kB)
# Using cached httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Using cached pyarrow-24.0.0-cp313-cp313-win_amd64.whl (27.3 MB)
# Using cached pydeck-0.9.2-py2.py3-none-any.whl (11.3 MB)
# Using cached python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Using cached starlette-1.3.1-py3-none-any.whl (73 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached websockets-16.0-cp313-cp313-win_amd64.whl (178 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# Installing collected packages: websockets, watchdog, toml, tenacity, smmap, python-multipart, pyarrow, protobuf, itsdangerous, httptools, cachetools, blinker, uvicorn, starlette, pydeck, gitdb, gitpython, altair, streamlit
# Successfully installed altair-6.2.1 blinker-1.9.0 cachetools-7.1.4 gitdb-4.0.12 gitpython-3.1.50 httptools-0.8.0 itsdangerous-2.2.0 protobuf-7.35.1 pyarrow-24.0.0 pydeck-0.9.2 python-multipart-0.0.32 smmap-5.0.3 starlette-1.3.1 streamlit-1.58.0 tenacity-9.1.4 toml-0.10.2 uvicorn-0.49.0 watchdog-6.0.0 websockets-16.0

# %%
import streamlit as st
print("Streamlit Installed Successfully!")
# Out:
# Streamlit Installed Successfully!

# %%
st.title("COVID-19 Dashboard")
st.write("Visualizing COVID-19 Cases Around the World")
# Out:
# 2026-06-22 18:57:02.709 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 18:57:03.057
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\KHUSHI RANI\.conda\envs\MyNewEnv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-22 18:57:03.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 18:57:03.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 18:57:03.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 18:57:03.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-22 18:57:03.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
